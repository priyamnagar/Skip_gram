# %%
import torch
from torch import nn,optim
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import os 
main_dir = os.path.join("..","input")

# %%
with open(os.path.join(main_dir,'text8')) as f:
    data=f.read()

# %%
from collections import Counter
def preprocess(text):
    text=text.lower()
    text=text.replace('.','<PERIOD>')
    text=text.replace('""','<QUOTATION_MARK>')
    text=text.replace(',','<COMMA>')
    text=text.replace(';','<SEMICOLON>')
    text=text.replace('!','<EXCLAMATION_MARK>')
    text=text.replace('?','<QUESTION_MARK>')
    text=text.replace('(','<LEFT_PAREN>')
    text=text.replace(')','<RIGHT_PAREN>')
    text=text.replace('-','<HYPHEN>')
    text=text.replace(':','<COLON>')
    words=text.split()
    
    word_count=Counter(words)
    trimmed_words=[word for word in words if word_count[word]>5]
    return trimmed_words

# %%
words=preprocess(data)

# %%
def create_lookup_tables(words):
    word_counts=Counter(words)
    
    sorted_vocab=sorted(word_counts, key=word_counts.get, reverse=True)
    
    int2vocab={i:word for word,i in enumerate(sorted_vocab)}
    
    vocab2int={word:i for i,word in int2vocab.items()}
    
    return int2vocab, vocab2int

# %%
vocab_to_int , int_to_vocab = create_lookup_tables(words)

# %%
int_words = [vocab_to_int[word] for word in words]
print(int_words[:30])
# Out:
# [5233, 3080, 11, 5, 194, 1, 3133, 45, 58, 155, 127, 741, 476, 10571, 133, 0, 27349, 1, 0, 102, 854, 2, 0, 15067, 58112, 1, 0, 150, 854, 3580]

# %% [markdown]
# SubSampling

# %%
import random
threshold=1e-5
total_count = len(int_words)
print(total_count)
word_counts=Counter(int_words)
frequency = {word:count/total_count for word,count in word_counts.items()}
p_drop = {word:1-np.sqrt(threshold/frequency[word]) for word in word_counts}
train_words = [word for word in int_words if (1-p_drop[word])>0.1]
# Out:
# 16680599

# %%
len(train_words)
# Out:
# 9032964

# %%
print(train_words[:30])
# Out:
# [5233, 3080, 194, 3133, 155, 127, 741, 476, 10571, 133, 27349, 102, 854, 15067, 58112, 150, 854, 3580, 194, 190, 10712, 214, 1324, 104, 454, 2731, 362, 3672, 708, 371]

# %% [markdown]
# Get Batches

# %%
def get_target(words,idx, window_size):
    R=np.random.randint(1,window_size+1)
    start=idx-R if idx-R>0 else 0 
    stop=idx+R
    target=words[start:idx]+words[idx+1:stop+1]
    return target
get_target(train_words,5,5)
# Out:
# [5233, 3080, 194, 3133, 155, 741, 476, 10571, 133, 27349]

# %%
def get_batches(words, batch_size, window_size):
    n_batches = len(words)//batch_size
    
    words=words[:n_batches*batch_size]
    for idx in range(0,len(words),batch_size):
            x=[]
            y=[]
            batch=words[idx:idx+batch_size]
            for i in range(len(batch)):
                batch_x=batch[i]
                batch_y=get_target(batch,i,window_size)
                x.extend([batch_x]*len(batch_y))
                y.extend(batch_y)
            yield x,y
            
                
                
x,y=next(get_batches(train_words, 4, 5))
print(x)
print(y)
# Out:
# [5233, 3080, 3080, 3080, 194, 194, 194, 3133]
# [3080, 5233, 194, 3133, 5233, 3080, 3133, 194]

# %%
def cosine_similarity(embedding, valid_size=16, valid_window=100, device='cpu'):
    """ Returns the cosine similarity of validation words with words in the embedding matrix.
        Here, embedding should be a PyTorch embedding module.
    """
    
    # Here we're calculating the cosine similarity between some random words and 
    # our embedding vectors. With the similarities, we can look at what words are
    # close to our random words.
    
    # sim = (a . b) / |a||b|
    
    embed_vectors = embedding.weight
    
    # magnitude of embedding vectors, |b|
    magnitudes = embed_vectors.pow(2).sum(dim=1).sqrt().unsqueeze(0)
    
    # pick N words from our ranges (0,window) and (1000,1000+window). lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples,
                               random.sample(range(1000,1000+valid_window), valid_size//2))
    valid_examples = torch.LongTensor(valid_examples).to(device)
    
    valid_vectors = embedding(valid_examples)
    similarities = torch.mm(valid_vectors, embed_vectors.t())/magnitudes
        
    return valid_examples, similarities

# %% [raw]
# Model

# %%
class SkipGram(nn.Module):
    def __init__(self,vocab,embed):
        super().__init__()
        self.embed=nn.Embedding(vocab,embed)
        self.out=nn.Linear(embed,vocab)
        self.log_soft=nn.LogSoftmax(dim=1)
    def forward(self,x):
        x=self.embed(x)
        x=self.out(x)
        x=self.log_soft(x)
        return x

# %%
model=SkipGram(len(vocab_to_int),300)
criterion=nn.NLLLoss()
optimizer=optim.Adam(model.parameters(),lr=0.003)
model.cuda()
# Out:
# SkipGram(
#   (embed): Embedding(63641, 300)
#   (out): Linear(in_features=300, out_features=63641, bias=True)
#   (log_soft): LogSoftmax()
# )

# %%
epochs=5
print_every=500
steps=0
for e in range(epochs):
    for inputs,targets in get_batches(train_words,512,5):
        steps+=1
        inputs , targets = torch.LongTensor(inputs) , torch.LongTensor(targets)
        inputs , targets = inputs.cuda() , targets.cuda()
        logits = model(inputs)
        loss = criterion(logits , targets)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if steps%print_every==0:
            valid_examples, valid_similarities = cosine_similarity(model.embed, device='cuda')
            _, closest_idxs = valid_similarities.topk(6) # topk highest similarities
            
            valid_examples, closest_idxs = valid_examples.to('cpu'), closest_idxs.to('cpu')
            for ii, valid_idx in enumerate(valid_examples):
                closest_words = [int_to_vocab[idx.item()] for idx in closest_idxs[ii]][1:]
                print(int_to_vocab[valid_idx.item()] + " | " + ', '.join(closest_words))
            print("...")
# Out:
# will | towering, ewald, gelder, wanderings, pete
# after | gemayel, nida, corriere, rabbits, parisian
# time | geometrically, codons, downstream, assembl, bends
# new | curium, sense, vacant, blight, groton
# of | seclusion, targum, kanu, monosodium, detonates
# state | sepp, nyc, medline, anjiro, viennese
# between | forint, arrhenius, clem, perfumery, weddell
# many | acc, informatics, becket, jefferson, doctor
# writers | pricking, galahad, weather, joshi, takers
# taking | streaming, yonkers, turpin, teshubah, fostered
# shown | receivers, despair, falcone, yuen, polytheism
# question | ballets, rantissi, ningen, mouthwash, bembo
# governor | dashes, eph, cdc, catalog, clairvaux
# gold | neonatal, takeo, sarti, nano, obelix
# san | votive, accompanied, schemes, unscrupulous, traps
# except | mink, kablooie, transducer, talked, bonuses
# ...
# that | crewmembers, multihulls, chico, technical, broadsheet
# one | auditioning, ouster, approx, dignity, blumenfeld
# called | medications, viennese, ioannes, theorized, atomists
# can | balmaceda, due, susan, coeur, degli
# is | bogged, authenticate, interphase, turks, centering
# between | arrhenius, forint, perfumery, woe, haze
# will | towering, ewald, wanderings, gelder, proceed
# of | seclusion, kanu, targum, monosodium, taylor
# placed | differences, amdahl, crawfish, sneeze, observers
# universe | stamina, botched, grueling, jurist, slang
# san | votive, accompanied, unscrupulous, schemes, traps
# troops | imperator, sultanates, delinquency, westphalian, render
# mean | cancels, shimon, scout, skenderbeg, perfectionism
# issue | remoteness, montt, jewishencyclopedia, gregorian, authorization
# bbc | reconsolidation, hurriedly, lanterns, elohim, callow
# smith | bhojpuri, rechargeable, canmore, scrotum, ignace
# ...
# who | morphogenesis, belgaum, florentines, archaelogical, decontamination
# of | seclusion, kanu, targum, taylor, monosodium
# american | approximating, maintained, samantha, heraclitus, tavola
# its | irritated, neq, naka, partement, yarmuk
# time | geometrically, codons, downstream, assembl, bends
# other | olanzapine, referee, qq, ermey, boeotian
# world | rale, trolling, inst, cliches, substratum
# used | intersexual, hypergiant, floss, merchant, bum
# lived | caffeine, subtitled, laomedon, interpreted, escap
# rise | maritimequest, cds, popolare, lymphoid, inapplicable
# discovered | resurrection, oppenheim, photographed, cavaliere, monastic
# additional | uncompressed, worships, constructor, convened, wickedness
# stage | agassi, jaffna, delivering, lloyd, discontinued
# versions | goods, ones, cubewanos, mls, scoreboard
# cost | vehicles, naturally, sixpence, boon, knapsack
# operating | lexicology, taint, duodenal, wadis, owned
# ...
# b | partnering, pianist, patmos, highlanders, defector
# this | emirates, hydrate, klima, szabo, dong
# states | staple, deforestation, charged, predisposition, amoeba
# other | olanzapine, referee, qq, ermey, boeotian
# new | sense, curium, groton, vacant, blight
# state | sepp, medline, viennese, anjiro, nyc
# where | decoherence, kierkegaard, margarine, pinafore, hermione
# if | govigama, cram, annuities, definitely, cassette
# brother | jo, spend, triphosphate, tittle, tetris
# applied | mathematical, fresco, dsl, airy, satellite
# arts | alumina, balzac, eldest, inklings, interchangeably
# grand | amelia, constitutionalism, ticino, cimmeria, middle
# alternative | ase, marwan, allgemeine, disappears, gluck
# discovered | resurrection, oppenheim, monastic, photographed, flagship
# hit | flaming, aristarchus, wholesale, seize, biddle
# bible | teodoro, anxiolytic, rope, homophobia, jenna
# ...
# if | govigama, cram, definitely, annuities, cassette
# been | franca, dyeing, expounding, episodes, microfiche
# at | recoilless, syndicates, gododdin, eriksson, bankhead
# state | sepp, medline, anjiro, nyc, canneries
# and | desiderius, shatz, cara, ufa, wieser
# zero | reciprocals, sufferers, unready, tricycle, adas
# world | rale, trolling, inst, cliches, montr
# have | prior, disturbances, sundarbans, regnum, escherichia
# liberal | aloof, appeals, roe, enamoured, cela
# running | stanislavski, kong, intimately, aquitaine, cambridgeshire
# rise | maritimequest, popolare, lymphoid, cds, inapplicable
# discovered | resurrection, oppenheim, photographed, monastic, flagship
# file | tradesmen, nuovo, diglossia, zbigniew, pressurised
# scale | exalted, fingers, rosemont, dupont, vulva
# bill | abbreviating, shem, fontsize, sequestered, maya
# alternative | ase, marwan, allgemeine, disappears, bollywood
# ...
# people | taniyama, oddity, prefectures, aggrieved, characterization
# all | hillery, bayezid, kerguelen, foy, elaborations
# five | nordisk, latvian, kapor, saville, gn
# most | stacks, increases, harmful, potsdamer, deflect
# new | curium, sense, groton, vacant, blight
# state | sepp, anjiro, medline, viennese, allergy
# it | scandals, kosovo, etymology, vitreous, gustave
# time | codons, geometrically, assembl, downstream, ibrd
# alternative | ase, marwan, allgemeine, disappears, bollywood
# existence | shaktism, gunmen, ineffable, remnant, polynomials
# freedom | bivouac, storytellers, allein, christy, kops
# pre | censor, ems, torts, woodstock, fates
# http | subservience, planks, issued, ripper, preslav
# stage | agassi, lloyd, jaffna, rann, delivering
# versions | goods, ones, cubewanos, antibacterial, scoreboard
# file | tradesmen, nuovo, diglossia, zbigniew, pressurised
# ...
# to | phospholipase, ousting, mohamad, ethyl, altruist
# th | dating, webzine, decentralization, hittite, jalisco
# be | rhoades, travelling, diurnal, zelda, smuggled
# used | intersexual, hypergiant, floss, stolen, bum
# if | govigama, annuities, cram, definitely, orators
# between | arrhenius, perfumery, roch, aida, inflict
# when | exam, installs, phonons, katarina, container
# are | incisors, techniques, mans, proffered, sulphate
# stage | agassi, lloyd, delivering, jaffna, rann
# applied | mathematical, dsl, fresco, satellite, langevin
# additional | uncompressed, constructor, convened, worships, wickedness
# operating | lexicology, duodenal, taint, wadis, carlisle
# institute | isabelle, graphically, mens, ketubah, marchers
# governor | castile, cdc, clairvaux, eph, dashes
# http | subservience, planks, issued, portal, bale
# report | buxtehude, cofounder, perishable, hab, galba
# ...
# they | kohn, christiane, bilirubin, chlorophyll, asserting
# was | vaud, shalom, hau, cupbearer, fedora
# years | holyrood, lebeau, essai, registry, python
# the | lipscomb, bordering, far, pseudopod, shag
# used | intersexual, hypergiant, floss, stolen, circulating
# when | exam, installs, phonons, katarina, container
# were | philologie, glimpsed, tissues, janis, kinetochores
# th | webzine, dating, daredevil, nineteenth, jalisco
# derived | volume, swapping, latin, cogs, messiah
# magazine | stephen, tonkin, flanders, udeac, hab
# brother | jo, spend, alai, tartu, triphosphate
# lived | caffeine, subtitled, escap, supernovae, laomedon
# operations | methods, maximizes, cytoplasmic, diane, footballer
# marriage | plural, cow, destructive, amicably, saith
# assembly | baar, donated, thereupon, grumman, alves
# heavy | literalism, besht, tamm, flit, sourcebook
# ...
# have | prior, disturbances, phenol, sundarbans, emptiness
# war | amphibious, arabidopsis, mcqueen, notification, juba
# four | epistle, tojo, endpin, multilingual, intervene
# for | cyclopentadienyl, chromatic, vacuole, odham, paracelsus
# by | franchisees, boisbaudran, thwarting, ra, winsor
# were | philologie, glimpsed, tissues, janis, kinetochores
# people | oddity, taniyama, prefectures, juche, latinized
# no | infraclass, prove, crandall, wc, remitted
# quite | penthouse, wonderful, kernels, fitting, esa
# shown | yuen, undermining, bundles, africa, tse
# nobel | cruciger, singer, underbrace, australian, copley
# frac | proudly, ambivalent, parthians, barbra, speyer
# institute | isabelle, graphically, mens, marchers, ketubah
# http | subservience, issued, planks, htm, portal
# san | votive, accompanied, danann, sylvan, schemes
# freedom | bivouac, allein, storytellers, christy, kops
# ...
# be | travelling, rhoades, diurnal, zelda, smuggled
# however | webzine, permanently, dentine, infections, virtues
# american | approximating, samantha, maintained, heraclitus, tavola
# with | befell, minimized, impingement, serfs, alkene
# they | kohn, christiane, solid, bilirubin, asserting
# of | seclusion, taylor, kanu, monosodium, targum
# over | nihilism, ten, cassia, johanson, antisocial
# their | solubility, aeroplanes, revealed, rohypnol, ketos
# grand | middle, keywords, sativa, mistletoe, amelia
# nobel | cruciger, singer, underbrace, obedient, copley
# smith | canmore, bhojpuri, ignace, exalted, rechargeable
# shows | jello, description, potion, rowan, dov
# creation | comecon, ablett, iigs, obsolescent, fossilized
# orthodox | covenants, natufian, abbe, nominally, metastability
# active | vorkosigan, linens, federation, lotta, atypical
# articles | romance, performa, shivering, vcs, woodwinds
# ...
# time | codons, geometrically, ibrd, assembl, downstream
# that | crewmembers, multihulls, technical, bight, broadsheet
# first | activision, solemn, hacker, amiable, active
# a | oued, minardi, lilitu, averaged, forte
# than | diverted, boac, geckos, francisco, excretion
# state | sepp, anjiro, mdi, nyc, canneries
# use | antibiotic, dominatrices, mobilization, willoughby, inducing
# at | recoilless, eriksson, fabricated, bankhead, transformational
# http | planks, subservience, issued, htm, ripper
# pre | torts, censor, ems, heckel, fates
# cost | vehicles, naturally, knapsack, sixpence, marjoram
# magazine | stephen, tonkin, flanders, udeac, youth
# prince | brugge, saracens, manpower, john, feinstein
# award | repertoire, nerva, alger, efta, times
# grand | middle, sativa, mistletoe, keywords, cimmeria
# applications | batch, lukewarm, aids, levelled, guides
# ...
# system | baffled, cameroons, offset, plexus, usefully
# have | prior, disturbances, sundarbans, ddd, phenol
# and | desiderius, shatz, wieser, cara, ufa
# some | provocative, minim, raincoat, egbert, dinara
# no | prove, crandall, hadith, wc, undisciplined
# where | decoherence, kierkegaard, niki, xy, blum
# to | phospholipase, ousting, mohamad, altruist, layperson
# but | machina, vinyl, anteater, glenn, variations
# recorded | linux, basenjis, lot, aeolic, arendt
# frac | parthians, ambivalent, speyer, gallantry, barbra
# lived | subtitled, caffeine, supernovae, laomedon, ellen
# freedom | bivouac, allein, storytellers, kops, emitter
# bbc | reconsolidation, statistical, gutar, almenr, obfuscated
# liberal | aloof, cela, appeals, roe, elamo
# behind | narration, follow, bounds, kanda, menacing
# police | oath, jab, alltel, irn, electrics
# ...
# zero | sufferers, reciprocals, unready, oc, declared
# an | obe, geddes, vocalists, satyr, aleksandrovich
# seven | advise, modalities, licensees, tito, luster
# often | diffused, chandler, afraid, perforce, wachowski
# if | govigama, zoological, annuities, cram, definitely
# on | dissident, kumar, satisfy, fritz, martensite
# time | codons, geometrically, ibrd, assembl, bends
# or | marder, legation, besson, adjoined, ch
# dr | echl, ja, test, nz, spur
# running | kong, subjection, stanislavski, cambridgeshire, intimately
# magazine | stephen, tonkin, youth, categorically, flanders
# units | willoughby, gros, granted, shrunk, ceefax
# additional | uncompressed, worships, convened, constructor, muscovy
# operations | mobilize, renditions, diane, maximizes, methods
# pope | menezes, jj, lateran, alison, gluon
# brother | jo, spend, alai, confess, salvius
# ...
# the | lipscomb, bordering, far, pseudopod, shag
# by | franchisees, thwarting, winsor, manatee, ra
# new | curium, sense, entity, blight, vacant
# would | lorenzo, vivekananda, brokered, imap, refugee
# this | emirates, hydrate, klima, szabo, dong
# united | everyman, canada, bedrooms, iulius, estates
# history | farthest, mcnair, ilayaraja, islander, dickinson
# s | hasdrubal, psychotherapy, regulatory, blur, understanding
# freedom | bivouac, allein, kops, rinehart, storytellers
# question | ballets, ningen, rantissi, stowed, elia
# prince | brugge, john, dyess, saracens, manpower
# liberal | aloof, cela, elamo, appeals, roe
# bbc | reconsolidation, gutar, almenr, callow, elohim
# centre | posh, emrys, hrvatske, consults, subsequently
# ice | gyges, hollow, headmaster, goeldi, monologue
# marriage | plural, ecc, ecs, married, ashur
# ...
# and | desiderius, shatz, wieser, ufa, contrapuntal
# or | marder, besson, ch, legation, exiguus
# no | prove, hadith, undisciplined, wc, sociological
# over | ten, nihilism, johanson, prevalence, glut
# world | rale, trolling, demeter, montr, dass
# three | brink, sphingomyelin, nutshell, lemma, travancore
# used | intersexual, hypergiant, saxophone, circulating, stolen
# was | vaud, shalom, hau, cupbearer, fedora
# pre | censor, torts, heckel, early, logographic
# scale | rosemont, reciprocating, leafy, vulva, northernmost
# construction | tara, ecce, vilna, shotokan, capitalism
# engineering | kets, disgruntled, management, evaluation, vannevar
# file | tradesmen, nuovo, facilitates, asymmetric, pressurised
# older | kava, pall, soon, dire, benevento
# http | htm, links, planks, subservience, issued
# gold | takeo, doon, sarti, neonatal, raiding
# ...
# nine | aime, oeis, triassic, nevsky, confesses
# war | vengeance, amphibious, diminishing, peckinpah, mcqueen
# who | morphogenesis, florentines, belgaum, mutation, storing
# not | michelson, airy, reasserting, biodiversity, smtp
# time | codons, geometrically, ibrd, assembl, bends
# th | nineteenth, twentieth, early, dating, mid
# its | irritated, neq, partement, naka, yarmuk
# in | entangled, hbp, acoustics, pocketed, aoraki
# frac | parthians, swap, speyer, gallantry, proudly
# applications | batch, files, aids, lukewarm, cie
# nobel | singer, australian, copley, underbrace, anatomist
# additional | uncompressed, constructor, worships, convened, muscovy
# issue | montt, remoteness, jewishencyclopedia, kassites, vitry
# units | willoughby, gros, shrunk, tetra, ceefax
# egypt | laden, peace, coral, regulated, endorses
# police | oath, jab, alltel, uncompleted, electrics
# ...
# over | nihilism, glut, ten, praetorian, versus
# a | oued, averaged, minardi, lilitu, skyrocketed
# use | antibiotic, using, antiderivatives, dxm, pint
# no | ablaut, undisciplined, prove, cliffordadams, hadith
# d | fairness, sidewalks, orphans, ucd, visuals
# have | prior, sundarbans, disturbances, escherichia, aggressiveness
# as | vicarage, misdiagnosed, gaming, psionic, kbe
# during | early, continued, allied, raffles, goliath
# marriage | married, ashur, categorisation, destructive, regimes
# resources | coot, mandrake, land, dials, wholesale
# arts | art, alumina, eldest, inklings, ogden
# pressure | combustion, vixen, songwriting, explosion, expand
# channel | viaduct, canals, oise, raytheon, observables
# ocean | ql, shakyamuni, deregulated, wretch, yellow
# scale | exalted, rosemont, reciprocating, leafy, northernmost
# bible | teodoro, anxiolytic, interpreted, paradigm, thecrimson
# ...
# is | sure, bogged, authenticate, interphase, enjoyable
# in | entangled, hbp, pocketed, aoraki, acoustics
# between | forint, scrip, speght, puree, subtract
# have | prior, disturbances, sundarbans, escherichia, aggressiveness
# been | dyeing, expounding, franca, microfiche, plainsong
# united | canada, america, iulius, seceded, everyman
# on | dissident, kumar, satisfy, fritz, conjugal
# up | sure, tuned, them, of, elle
# scale | exalted, rosemont, reciprocating, leafy, tenths
# report | buxtehude, hab, cofounder, galba, quadrilateral
# hold | stabilizers, odd, decorated, secrecy, nonhuman
# event | aged, obese, recession, fyodorovna, no
# grand | cimmeria, sativa, farr, pogues, macarthur
# primarily | epilepsy, selection, upper, islamiyah, zmir
# engineering | kets, disgruntled, management, evaluation, vannevar
# existence | izmir, gunmen, taoists, shaktism, mercalli
# ...
# all | hillery, bayezid, kerguelen, foy, authorising
# be | travelling, rhoades, diurnal, smuggled, zelda
# one | auditioning, dignity, ouster, approx, blumenfeld
# system | hemionus, cameroons, infrastructure, systems, offset
# there | elstree, contacting, increments, controls, curly
# see | antoni, feodor, operationally, lrc, acme
# these | heliocentrism, verisimilitude, dad, ordinary, kitchen
# known | regarded, considered, ruth, godfrey, pharmacokinetics
# notes | burnham, bova, monadic, curds, carcinoma
# pope | jj, lateran, menezes, council, episodic
# dr | test, ja, interview, crap, donna
# orthodox | covenants, natufian, doraemon, sundance, altars
# mainly | renin, stanislaus, islands, bsl, cathar
# defense | mamet, lotus, bundeswehr, kamon, ono
# shown | undermining, tamburlaine, yuen, despair, bundles
# active | linens, vorkosigan, polyidus, federation, ancus
# ...
# are | incisors, proffered, techniques, anh, sulphate
# these | heliocentrism, verisimilitude, dad, ordinary, kitchen
# it | scandals, gustave, kosovo, etymology, vitreous
# history | links, protolanguage, ilayaraja, cuisines, isbn
# used | intersexual, saxophone, hypergiant, floss, stolen
# first | activision, solemn, hacker, amiable, lodgings
# as | vicarage, misdiagnosed, gaming, incubated, psionic
# of | seclusion, targum, kanu, taylor, up
# heavy | literalism, besht, annihilate, politic, flit
# taking | took, turpin, boles, yonkers, besieged
# hit | albums, flaming, wholesale, aristarchus, judaeo
# operations | occupation, cytoplasmic, mobilize, footballer, soldiers
# older | kava, soon, dire, pall, perinatal
# shows | rowan, jello, description, dov, weekday
# pre | torts, early, censor, ems, heckel
# police | oath, jab, guards, guardia, alltel
# ...
# who | mutation, belgaum, morphogenesis, decontamination, euratom
# were | philologie, glimpsed, tissues, janis, kinetochores
# there | elstree, contacting, increments, curly, controls
# can | nicaea, due, balmaceda, prolog, coeur
# of | seclusion, targum, kanu, taylor, up
# used | intersexual, circulating, saxophone, hypergiant, stolen
# which | filipino, pickwick, trouble, replicate, tcl
# also | salla, ourselves, hernandez, directions, motilal
# pope | lateran, jj, menezes, bhagavad, council
# egypt | laden, dogs, wentworth, venetian, peace
# primarily | selection, epilepsy, upper, islamiyah, hateful
# brother | jo, spend, confess, alai, salvius
# behind | ineffectual, narration, rationalistic, kanda, reversed
# additional | uncompressed, constructor, dimensional, muscovy, convened
# engine | powerplant, spacesuit, dumping, repeaters, formats
# articles | romance, performa, fao, vcs, dreamworks
# ...
# about | approximately, roughly, chicanos, comical, around
# which | replicate, pickwick, trouble, filipino, tcl
# also | salla, ourselves, hernandez, directions, motilal
# would | vivekananda, lorenzo, imap, brokered, refugee
# between | over, during, speght, dux, carlow
# however | although, though, slowly, micron, citeaux
# has | inertial, curfews, decomposed, programming, maduro
# often | usually, sometimes, generally, widely, frequently
# lived | caffeine, escap, subtitled, laomedon, hmcs
# http | htm, links, portal, planks, subservience
# writers | dramatists, composers, pricking, anka, bacchus
# cost | vehicles, intranet, sixpence, marjoram, enact
# active | linens, vorkosigan, ancus, federation, airways
# question | debate, ballets, weblogs, sought, substitutions
# heavy | literalism, besht, annihilate, flit, politic
# know | so, what, njazidja, afterburner, t
# ...
# known | called, regarded, although, considered, referred
# s | regulatory, hasdrubal, blur, understanding, psychotherapy
# state | anjiro, virion, sepp, canneries, prohibited
# such | scullard, gorillas, usurpers, agonist, sta
# six | cares, message, atzma, tsarevich, valence
# new | curium, groton, sense, entity, realms
# however | although, though, slowly, next, micron
# a | oued, averaged, lilitu, conceives, skyrocketed
# numerous | guesses, punjabi, chambers, tadpoles, guip
# except | mink, tilings, talked, quoque, poetess
# square | km, cotes, higham, area, archer
# units | willoughby, shrunk, bylaw, gros, vikings
# applied | mathematical, coined, langevin, magnificence, lutetium
# articles | drabble, dreamworks, fao, vcs, performa
# gold | takeo, sarti, doon, ulterior, raiding
# police | guards, oath, alltel, guardia, jab
# ...
# seven | advise, modalities, tito, licensees, burnley
# not | airy, michelson, reasserting, biodiversity, smtp
# people | americans, persons, cantors, natives, sociologists
# on | dissident, kumar, satisfy, fritz, conjugal
# many | acc, informatics, privatizations, jefferson, ultramarine
# may | ethereal, yoritomo, harmony, slugging, revolutionize
# these | heliocentrism, ordinary, dad, verisimilitude, kitchen
# up | down, them, elle, back, out
# something | what, spectrum, gemeinde, questions, reasons
# quite | very, penthouse, wonderful, stirring, rabbinic
# cost | vehicles, sixpence, intranet, condescending, marjoram
# institute | isabelle, graphically, mens, empathy, undergraduate
# hit | albums, flaming, hornbill, previous, cowboys
# recorded | linux, recording, basenjis, martyr, tuesday
# question | know, debate, cannot, questions, sought
# event | aged, obese, recession, fyodorovna, hydrofluoric
# ...
# seven | modalities, advise, tito, licensees, evangelical
# also | salla, ourselves, hernandez, relayed, directions
# people | americans, persons, cantors, natives, majority
# at | recoilless, endeavoring, syndicates, shiraz, bankhead
# zero | sufferers, declared, unready, reciprocals, adas
# and | desiderius, wieser, shatz, midfielder, ufa
# of | seclusion, taylor, kanu, targum, monosodium
# it | scandals, gustave, kosovo, etymology, vitreous
# placed | amdahl, hansa, mercantilist, sneeze, lazare
# http | htm, links, portal, html, net
# recorded | linux, martyr, basenjis, recording, lot
# grand | farr, macarthur, cimmeria, ring, axum
# pope | lateran, jj, menezes, bhagavad, anointed
# engineering | research, kets, disgruntled, management, evaluation
# quite | very, stirring, less, penthouse, ways
# freedom | prohibitive, rinehart, bivouac, luxembourgish, storytellers
# ...
# not | airy, michelson, reasserting, smtp, wwe
# which | replicate, trouble, filipino, pickwick, tcl
# used | intersexual, circulating, floss, lively, hypergiant
# there | elstree, contacting, increments, central, bragging
# one | auditioning, dignity, approx, ouster, blumenfeld
# but | machina, vinyl, anteater, zhdanov, isocrates
# when | exam, installs, katarina, borders, zanu
# or | marder, cambridge, besson, unamsil, exiguus
# quite | very, ways, kohoutek, stirring, penthouse
# bible | teodoro, interpreted, paradigm, scripture, thecrimson
# test | pedagogue, compiling, dr, infrequently, bandwagon
# nobel | underbrace, copley, prize, singer, laureates
# construction | tara, vicinity, amplitudes, grizzly, stuffy
# centre | posh, heterozygosity, consults, emrys, jun
# know | what, so, question, things, tell
# channel | gated, observables, communication, canals, network
# ...
# four | tojo, epistle, constitution, hanukkah, muslim
# there | elstree, contacting, increments, bragging, schule
# in | hbp, pocketed, entangled, repute, freyja
# during | early, before, began, end, th
# to | phospholipase, religions, mohamad, ethyl, altruist
# than | boac, excretion, geckos, diverted, falciparum
# as | misdiagnosed, vicarage, incubated, gaming, psionic
# a | oued, averaged, lilitu, conceives, minardi
# derived | latin, based, volume, cogs, emptiness
# nobel | prize, chemist, australian, physiology, singer
# award | grammy, alger, genre, efta, earning
# hold | mustafa, odd, stabilizers, nonhuman, grouse
# engineering | management, kets, research, disgruntled, computer
# animals | humans, normalcy, after, plants, mammals
# mainly | islands, mcdonald, amorites, bsl, renin
# governor | governors, clairvaux, castile, simo, bolger
# ...
# used | intersexual, circulating, floss, saxophone, hypergiant
# united | america, u, states, canada, member
# a | oued, averaged, lilitu, bounding, conceives
# system | systems, hemionus, centrist, demiurge, cameroons
# war | army, battle, bomber, during, forces
# seven | modalities, advise, tito, licensees, evangelical
# been | franca, dyeing, expounding, microfiche, plainsong
# that | crewmembers, multihulls, bight, collaborations, chico
# centre | posh, heterozygosity, consults, latch, jun
# defense | mamet, kamon, bundeswehr, stds, treasury
# numerous | several, including, include, guesses, guip
# operations | methods, cytoplasmic, occupation, undergraduates, espionage
# issue | montt, remoteness, bowl, kassites, debate
# egypt | peace, laden, charlton, wentworth, dogs
# primarily | epilepsy, selection, affluent, variance, multipart
# know | what, t, so, things, think
# ...
# after | gemayel, animals, nida, rabbits, corriere
# while | capable, cebus, she, even, tapped
# and | shatz, wieser, desiderius, midfielder, extrapolation
# into | bilayers, skelter, diverged, succinic, artistry
# first | activision, solemn, amiable, hacker, robes
# which | replicate, filipino, trouble, pickwick, her
# that | crewmembers, multihulls, chico, collaborations, fas
# at | recoilless, syndicates, headquarters, shiraz, dictionaries
# running | kong, ellen, drilled, lehi, hypnotists
# experience | positivist, traceable, phenomenal, darjeeling, emmer
# older | kava, soon, wargaming, burgos, dire
# creation | comecon, chandrasekhar, rudolph, obsolescent, hallows
# assembly | elected, alves, habib, fleischer, thereupon
# behind | left, rumsfeld, ineffectual, rationalistic, reversed
# institute | isabelle, undergraduate, award, graphically, empathy
# dr | michael, test, donna, ja, robles
# ...
# however | although, since, though, because, while
# may | ethereal, yoritomo, slugging, oligarchic, paternalistic
# d | fairness, visuals, ucd, raincoat, sidewalks
# they | kohn, christiane, busiest, bilirubin, trams
# a | oued, lilitu, bounding, conceives, averaged
# as | misdiagnosed, vicarage, gaming, incubated, monasteries
# often | sometimes, usually, generally, widely, occasionally
# he | caucasus, elebi, travolta, fille, overgrown
# grand | prussia, cimmeria, netherlands, maria, farr
# experience | positivist, traceable, darjeeling, phenomenal, emmer
# arts | art, spahn, institutions, alumina, inklings
# police | guards, sle, guardia, oath, intellectuals
# articles | review, drabble, fao, erskine, story
# prince | brugge, shula, anhalt, succeeded, sister
# numerous | several, including, those, include, various
# gold | silver, takeo, african, mouthwash, doon
# ...
# which | replicate, trouble, filipino, pickwick, tcl
# there | elstree, contacting, controls, increments, bragging
# nine | aime, nevsky, triassic, oeis, usages
# that | crewmembers, multihulls, chico, bight, collaborations
# d | fairness, visuals, ucd, tempel, raincoat
# an | obe, geddes, creator, aleksandrovich, altos
# three | sphingomyelin, nutshell, brink, viswanathan, angers
# called | referred, known, named, based, considered
# something | what, you, questions, gemeinde, really
# animals | species, humans, plants, human, diseases
# scale | number, leafy, tdma, rosemont, demeaning
# paris | france, switzerland, kitchener, hypatia, de
# ice | hollow, goeldi, headmaster, varna, ribs
# derived | latin, name, called, abbreviation, emptiness
# proposed | notified, nowell, muscovy, rediscovery, caress
# square | area, km, walls, arbitron, higham
# ...
# american | samantha, tavola, illustrators, approximating, trivium
# often | sometimes, usually, generally, frequently, simply
# new | curium, realms, groton, neuromancer, joram
# nine | aime, triassic, nevsky, oeis, usages
# that | crewmembers, multihulls, chico, bight, rollin
# state | government, mississippi, anjiro, nebraska, federal
# during | early, end, before, began, war
# these | ordinary, dad, heliocentrism, verisimilitude, kitchen
# running | system, kong, hypnotists, bit, drilled
# joseph | matthew, murder, eugene, robert, chondrichthyes
# woman | young, children, she, women, pregnant
# account | tertullian, gaff, monads, anomalies, journals
# egypt | mesopotamia, peace, muhammad, charlton, dynasty
# pre | early, exoplanets, heckel, torts, attrition
# something | what, you, questions, gemeinde, things
# taking | took, take, taken, takes, palliative
# ...
# called | referred, known, named, considered, refers
# if | then, always, will, might, you
# at | recoilless, shiraz, dsph, endeavoring, france
# were | philologie, glimpsed, tissues, kinetochores, morrie
# after | gemayel, rabbits, animals, nida, infirmary
# use | using, available, usage, uses, kanji
# however | although, though, since, any, because
# so | what, because, know, too, however
# ice | hollow, goeldi, headmaster, varna, ribs
# grand | netherlands, prussia, maria, cimmeria, axum
# nobel | prize, chemist, physiology, winners, born
# applications | files, bac, reactions, raytheon, extensions
# proposed | nowell, notified, caress, muscovy, challenged
# construction | constructed, stuffy, centris, tara, building
# brother | jo, dynasty, alai, throne, claimed
# prince | succeeded, emperor, anhalt, brugge, king
# ...
# often | sometimes, usually, generally, commonly, well
# see | antoni, feodor, victor, operationally, lrc
# states | kingdom, nations, countries, u, united
# eight | plant, giscard, mama, bottleneck, durer
# there | elstree, contacting, controls, bragging, increments
# however | although, though, any, so, because
# these | ordinary, dad, heliocentrism, verisimilitude, bar
# at | recoilless, shiraz, dsph, endeavoring, gododdin
# bible | teodoro, interpreted, scripture, paradigm, andechs
# additional | uncompressed, adequate, shirts, mementos, rules
# question | questions, debate, know, cannot, whether
# accepted | regarded, developed, alexa, interoperability, sorel
# police | convicted, guards, guardia, wounded, pardons
# discovered | oppenheim, asteroids, discoveries, serres, vid
# mean | root, low, vertices, estimation, density
# san | francisco, mall, di, evangelic, ndez
# ...
# one | auditioning, dignity, ouster, approx, kidney
# can | coeur, began, balmaceda, nicaea, prolog
# than | excretion, geckos, boac, falciparum, sanitation
# it | scandals, gustave, etymology, vitreous, marx
# by | technology, franchisees, manatee, astrophysics, boisbaudran
# two | earthy, docteur, abated, paladin, disputes
# has | inertial, decomposed, curfews, scans, pearly
# when | exam, muhammed, installs, prawns, katarina
# construction | constructed, stuffy, indicator, tara, tunnel
# smith | canmore, gleason, nelson, ambush, kay
# proposed | nowell, introduced, developed, biologists, foremost
# troops | forces, army, invasion, stationed, polices
# governor | governors, politician, simo, simon, bolger
# ice | hollow, goeldi, ribs, headmaster, photovoltaic
# mainly | often, renin, bremen, amorites, roughly
# older | wargaming, developing, kava, leisure, dag
# ...
# s | regulatory, hasdrubal, algebra, understanding, blur
# use | using, usage, uses, describe, available
# one | auditioning, dignity, ouster, kidney, approx
# than | excretion, geckos, boac, falciparum, sanitation
# are | incisors, proffered, width, sulphate, anh
# he | elebi, caucasus, travolta, lasts, overgrown
# eight | plant, giscard, mama, bottleneck, bullough
# into | bilayers, skelter, deleted, succinic, diverged
# question | questions, know, debate, cannot, whether
# assembly | council, elected, house, baar, legislative
# pope | pius, lateran, emperor, king, church
# scale | leafy, number, size, skanderbeg, tdma
# engineering | management, electrical, computer, kets, aviation
# know | think, what, so, agree, do
# road | touma, roads, mimicking, routes, paved
# report | reports, noriega, recommended, january, case
# ...
# th | st, early, nd, late, mid
# in | pocketed, milestone, repute, entangled, hbp
# no | any, longer, however, does, because
# was | vaud, shalom, cupbearer, antiparticle, hau
# can | coeur, began, nicaea, prolog, alligator
# years | year, months, days, age, decades
# by | technology, franchisees, manatee, astrophysics, boisbaudran
# states | kingdom, nations, u, america, countries
# account | tertullian, monads, anomalies, journals, book
# dr | michael, ja, musik, malone, phobia
# creation | cleary, created, creating, iigs, fon
# discovered | found, named, oppenheim, observed, earliest
# test | pedagogue, rails, dr, srpska, bandwagon
# articles | article, review, submitted, published, magazine
# bible | teodoro, book, text, christian, interpreted
# operations | operation, methods, applications, implemented, cotangent
# ...
# than | geckos, excretion, boac, falciparum, sanitation
# of | taylor, kanu, seclusion, draped, homophobia
# he | elebi, caucasus, lasts, travolta, dag
# but | machina, vinyl, anteater, charleroi, clis
# six | cares, valence, message, atzma, endothermic
# from | incredibly, inoculate, love, dent, progeny
# into | bilayers, skelter, hurricane, deleted, hotelier
# people | americans, persons, natives, thousands, things
# articles | article, review, magazine, published, submitted
# engineering | computer, building, management, electrical, engineer
# prince | succeeded, daughter, anhalt, emperor, king
# instance | smells, example, cheerful, descending, therein
# units | unit, shrunk, willoughby, about, meter
# discovered | found, named, earliest, oppenheim, serres
# professional | association, teams, fitness, athletes, professionals
# defense | stds, missile, deployment, ifvs, mamet
# ...
# a | oued, bounding, lilitu, conceives, minardi
# eight | plant, giscard, quickly, mama, bottleneck
# not | airy, michelson, reasserting, observatories, smtp
# and | shatz, wieser, burger, desiderius, extrapolation
# only | youngman, zip, reactor, labrador, beeb
# his | conductors, reestablishing, refrigerants, clearwater, rhotic
# into | st, bilayers, skelter, hurricane, deleted
# six | cares, valence, message, atzma, endothermic
# bill | david, arnold, reed, interleague, ronald
# instance | descending, example, smells, discarding, therein
# police | pardons, guards, guardia, convicted, military
# ocean | sea, islands, submarine, eutelsat, river
# file | version, information, windows, software, files
# frac | x, barbra, right, n, tissue
# older | wargaming, kava, developing, soon, younger
# channel | network, radio, communication, broadcast, tv
# ...
# during | before, early, began, late, beginning
# other | olanzapine, referee, ermey, rampart, qq
# at | recoilless, exp, france, syndicates, dsph
# use | using, usage, uses, available, usually
# have | prior, seeing, disturbances, inertia, hubble
# zero | oc, reciprocals, sufferers, unready, luzon
# can | coeur, nicaea, prolog, balmaceda, snub
# d | fairness, tempel, ucd, phylogenetically, orphans
# bible | teodoro, text, book, interpreted, paradigm
# articles | article, published, magazine, history, review
# primarily | epilepsy, mainly, chaker, largely, hybrid
# orthodox | church, christian, catholic, christianity, churches
# bbc | news, aired, links, pri, external
# issue | issues, dispute, controversy, montt, debate
# brother | father, son, jo, wife, throne
# bill | david, arnold, ronald, reed, sequestered
# ...
# states | nations, kingdom, u, countries, united
# who | storing, morphogenesis, subgroups, pva, mutation
# or | emphasis, marder, exiguus, capitalization, alcs
# are | incisors, width, proffered, anh, hagar
# people | deaths, births, americans, natives, things
# over | under, nearly, every, off, between
# is | enjoyable, authenticate, interphase, yearning, sure
# was | vaud, shalom, cupbearer, antiparticle, czapski
# accepted | regarded, considered, understandings, although, historians
# event | events, obese, slams, celebrations, peltier
# additional | uncompressed, triple, adequate, muscovy, galatasaray
# derived | latin, word, means, etymology, root
# san | francisco, los, california, de, di
# shows | show, series, movies, description, pdl
# running | run, narrow, runs, drilled, subjection
# road | roads, rail, routes, mimicking, touma
# ...
# one | auditioning, ouster, dignity, approx, gland
# its | neq, films, irritated, naka, yarmuk
# this | hydrate, klima, insurance, szabo, emirates
# during | end, early, before, throughout, beginning
# such | scullard, gorillas, usurpers, collectivist, agonist
# been | franca, dyeing, microfiche, carbohydrate, expounding
# other | olanzapine, ermey, referee, rampart, qq
# had | derek, archaeologist, nathanael, monopolized, dueling
# marriage | married, daughter, her, wife, children
# construction | tunnel, constructed, building, charlottenburg, built
# arts | art, architecture, academy, alumina, college
# square | area, km, street, walls, surrounded
# primarily | epilepsy, mostly, patois, hybrid, customizing
# notes | bova, bar, fanu, upbeat, ifconfig
# articles | article, information, history, magazine, published
# versions | version, ones, windows, variants, original
# ...
